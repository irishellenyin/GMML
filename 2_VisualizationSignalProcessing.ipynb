# %% [markdown]
# ## 2. PyCBC Tutorial: Visualization of Data and Signal Processing
#
# We will be using the [PyCBC](http://github.com/ligo-cbc/pycbc) library, which is used to study gravitational-wave data, find astrophysical sources due to compact binary mergers, and study their parameters. These are some of the same tools that the LIGO and Virgo collaborations use to find gravitational waves in LIGO/Virgo data
#
# In this tutorial we will walk through how to visualize LIGO/Virgo data and how to perform some basic signal processing on it, including high/low passing, psd estimation, and whitening.
#
# Additional [examples](http://pycbc.org/pycbc/latest/html/#library-examples-and-interactive-tutorials) and module level documentation are [here](http://pycbc.org/pycbc/latest/html/py-modindex.html)

# %% [markdown]
# #### Getting the software environment setup
#
# PyCBC is installable through pip, but also relies on portions of the [LALSuite](git.ligo.org/lscsoft/lalsuite) c-library. A bundled version of this suitable for use with PyCBC is also available on Mac / Linux through pip. These can be installed as follows within the notebook.

# %%
import sys
# !{sys.executable} -m pip install pycbc ligo-common --no-cache-dir
# Out:
# Collecting pycbc
#   Downloading PyCBC-2.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting ligo-common
#   Downloading ligo_common-1.0.3-py2.py3-none-any.whl (2.0 kB)
# Collecting lscsoft-glue>=1.59.3
#   Downloading lscsoft-glue-3.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.4 MB/s eta 0:00:0031m28.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.16.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (1.21.5)
# Collecting Mako>=1.0.1
#   Downloading Mako-1.2.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 217.2 MB/s eta 0:00:00
# Collecting gwdatafind
#   Downloading gwdatafind-1.1.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 161.1 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (4.11.1)
# Collecting mpld3>=0.3
#   Downloading mpld3-0.5.8-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (4.64.0)
# Requirement already satisfied: pillow in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (9.0.1)
# Requirement already satisfied: jinja2 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (2.11.3)
# Requirement already satisfied: scipy>=0.16.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (1.7.3)
# Requirement already satisfied: setuptools in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (61.2.0)
# Collecting lalsuite!=7.2
#   Downloading lalsuite-7.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: matplotlib>=1.5.1 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (3.5.1)
# Requirement already satisfied: cython>=0.29 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (0.29.28)
# Requirement already satisfied: astropy!=4.0.5,!=4.2.1,>=2.0.3 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (5.0.4)
# Requirement already satisfied: h5py>=3.0.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from pycbc) (3.6.0)
# Collecting pegasus-wms.api>=5.0.1
#   Downloading pegasus-wms.api-5.0.2.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ligo-segments
#   Downloading ligo-segments-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting python-ligo-lw>=1.7.0
#   Downloading python-ligo-lw-1.8.3.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=19.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (21.3)
# Requirement already satisfied: pyerfa>=2.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in /home/iris/anaconda3/lib/python3.9/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (6.0)
# Requirement already satisfied: soupsieve>1.2 in /home/iris/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.6.0->pycbc) (2.3.1)
# Requirement already satisfied: python-dateutil in /home/iris/anaconda3/lib/python3.9/site-packages (from lalsuite!=7.2->pycbc) (2.8.2)
# Collecting pyRXP
#   Downloading pyRXP-3.0.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.9/297.9 kB 3.6 MB/s eta 0:00:003.4 MB/s eta 0:00:01
# Requirement already satisfied: pyOpenSSL in /home/iris/anaconda3/lib/python3.9/site-packages (from lscsoft-glue>=1.59.3->pycbc) (21.0.0)
# Requirement already satisfied: six in /home/iris/anaconda3/lib/python3.9/site-packages (from lscsoft-glue>=1.59.3->pycbc) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/iris/anaconda3/lib/python3.9/site-packages (from Mako>=1.0.1->pycbc) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/iris/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.5.1->pycbc) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.5.1->pycbc) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/iris/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.5.1->pycbc) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /home/iris/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.5.1->pycbc) (0.11.0)
# Collecting pegasus-wms.common
#   Downloading pegasus-wms.common-5.0.2.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 7.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting igwn-auth-utils>=0.3.1
#   Downloading igwn_auth_utils-0.3.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: cryptography>=2.3 in /home/iris/anaconda3/lib/python3.9/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.4.8)
# Collecting scitokens>=1.7.0
#   Downloading scitokens-1.7.0-py3-none-any.whl (23 kB)
# Collecting safe-netrc>=1.0.0
#   Downloading safe_netrc-1.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: requests>=2.14 in /home/iris/anaconda3/lib/python3.9/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.27.1)
# Requirement already satisfied: cffi>=1.12 in /home/iris/anaconda3/lib/python3.9/site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/iris/anaconda3/lib/python3.9/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/iris/anaconda3/lib/python3.9/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/iris/anaconda3/lib/python3.9/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/iris/anaconda3/lib/python3.9/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.0.4)
# Requirement already satisfied: PyJWT>=1.6.1 in /home/iris/anaconda3/lib/python3.9/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.4.0)
# Requirement already satisfied: pycparser in /home/iris/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.21)
# Building wheels for collected packages: lscsoft-glue, pegasus-wms.api, python-ligo-lw, ligo-segments, pegasus-wms.common
#   Building wheel for lscsoft-glue (pyproject.toml) ... done
#   Created wheel for lscsoft-glue: filename=lscsoft_glue-3.0.1-cp39-cp39-linux_x86_64.whl size=214454 sha256=88af4f408194f57be462918304b66c1df6c4464f38067e3f6cc672e8fe1c6120
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06l6agvo/wheels/49/14/fb/7969947b8a18347925a86d2f70e7f600512ed7857bc5cfe9b0
#   Building wheel for pegasus-wms.api (pyproject.toml) ... done
#   Created wheel for pegasus-wms.api: filename=pegasus_wms.api-5.0.2-py3-none-any.whl size=49910 sha256=596da22127aa6550295550d34d7005ff5456c38191faca99f8e81d8df8042e76
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06l6agvo/wheels/5a/fb/65/476c9f5cc97a87a83ccff541db26796c80f779a56d314b3e52
#   Building wheel for python-ligo-lw (setup.py) ... done
#   Created wheel for python-ligo-lw: filename=python_ligo_lw-1.8.3-cp39-cp39-linux_x86_64.whl size=133220 sha256=08e7c4c2b3a1e178a3726ac943360ce3daa7178faadf76c066d7a0f5d3dcebaa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06l6agvo/wheels/24/4a/01/2b07c68ddef2b4de5051b79a49fb1f9a80a93b075cbf6f3269
#   Building wheel for ligo-segments (setup.py) ... done
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp39-cp39-linux_x86_64.whl size=51073 sha256=8fd37cefe45b531d5dc523f3eb7585fc4f9651f8562d400673540851b750e47a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06l6agvo/wheels/bf/48/4b/3b25ac327f65168ccf3ca1f7321bb533db6de5123847f9c6f7
#   Building wheel for pegasus-wms.common (pyproject.toml) ... done
#   Created wheel for pegasus-wms.common: filename=pegasus_wms.common-5.0.2-py3-none-any.whl size=46237 sha256=f2b63349de9fccee0ad397c8963f13ea96ee794707c1b93209a5b5924c1e29ea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06l6agvo/wheels/e9/9e/fd/aa22ba0dde5d8834c120bc8d78b172e7156f76b0a299a208a6
# Successfully built lscsoft-glue pegasus-wms.api python-ligo-lw ligo-segments pegasus-wms.common
# Installing collected packages: safe-netrc, ligo-common, pyRXP, pegasus-wms.common, Mako, ligo-segments, pegasus-wms.api, scitokens, mpld3, lscsoft-glue, igwn-auth-utils, python-ligo-lw, lalsuite, gwdatafind, pycbc
# Successfully installed Mako-1.2.3 gwdatafind-1.1.2 igwn-auth-utils-0.3.1 lalsuite-7.10 ligo-common-1.0.3 ligo-segments-1.4.0 lscsoft-glue-3.0.1 mpld3-0.5.8 pegasus-wms.api-5.0.2 pegasus-wms.common-5.0.2 pyRXP-3.0.1 pycbc-2.0.5 python-ligo-lw-1.8.3 safe-netrc-1.0.0 scitokens-1.7.0

# %% [markdown]
# #### Viewing the raw LIGO data
#
# Below we will view the raw ligo data. You should notice that there is signifant low frequency content (indicated by the large oscilations) and even some DC offset in the data.

# %%
# %matplotlib inline

# Read in the data around GW150914
from pycbc.catalog import Merger
import pylab

m = Merger('GW150914')

data = {}
for ifo in ['H1', 'L1']:
    data[ifo] = m.strain(ifo)

# %% [markdown]
# ##### Entire 32 seconds of data round GW150914

# %%
for ifo in data:
    pylab.plot(data[ifo].sample_times, data[ifo], label=ifo)

pylab.ylabel('Strain')
pylab.xlabel('GPS Time (s)')
pylab.legend()
pylab.show()

# %% [markdown]
# ##### Zoom into 1 second nearby to GW150914
#
# When you just zoom in to one second around GW150914, all you can see is the low frequency behavior of the noise, since it is much louder than the higher frequency noise (and signal).

# %%
for ifo in data:
    # The time slice method can give just a portion of the time
    # series using GPS start and stop times
    zoom = data[ifo].time_slice(m.time - 0.5, m.time + 0.5)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.legend()
pylab.show()

# %% [markdown]
# #### Highpass the data to remove the low frequency content
#
# Below we apply a highpass filter to the data to suppress the low frequency noise of the instrument. We can see that this brings the dynamic range of the data largely into the same range. However, there is clearly still some dominant frerquencies. To equalize this, we would need to apply a whitening filter.

# %%
for ifo in data:
    # Apply a highpass filter to the data. This suppresses the low
    # frequency content of the data. We choose here a finite-impulse-response (FIR).
    # Options
    # 1) highpass frequency
    # 2) half sample length of highpass filter 
    #(higher value will give less ripple in passband)
    high_data = data[ifo].highpass_fir(15, 512) # Highpass point is 15 Hz
        
    # The time slice method can give just a portion of the time
    # series using GPS start and stop times
    zoom = high_data.time_slice(m.time - 0.5, m.time + 0.5)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.legend()
pylab.show()
print(len(zoom))
# Out:
# 4096

# %% [markdown]
# #### What is the power spectral density (PSD) of the data ?
#
# Understanding how the noise power varies over frequency is important for LIGO data analysis. In this
# section we use a version of [Welch's method](https://en.wikipedia.org/wiki/Welch%27s_method)
# to estimate the power spectral density of the data.
#
# Note that there is a significant amount of noise at low frequencies (orders of magnitude). Note also that there is a large amount of power at a few specific frequencies. The causes for these include 60 Hz power line noise, violin modes of the hanging mirrors, and various other instrumental resonances. The downturn in power before 2 KHz is due to a low pass filter that was applied prior to resampling the data to 4096 Hz.

# %%
for ifo in data:
    # This estimates the PSD by sub-dividing the data into overlapping
    # 4s long segments. (See Welch's method)
    psd = data[ifo].psd(4)
    
    # Note that the psd is a FrequencySeries!
    pylab.loglog(psd.sample_frequencies, psd)
    
pylab.ylabel('$Strain^2 / Hz$')
pylab.xlabel('Frequency (Hz)')
pylab.grid()
pylab.xlim(10, 2048)
pylab.show()

# %% [markdown]
# #### Whitening the data
#
# To visualize deviations from the noise, it is useful to "whiten" the data within some frequency range. In this way excesses in the data are visible as deviations from zero. Whitening takes the data and attempts to make the power spectral density flat, so that all frequencies contribute equally.
#
# Below we will whiten the data, and then bandpass the result to focus on a specific frequency range.

# %%
# Whiten the data
whitened = {}

for ifo in data:
    # This produces a whitened set.
    # This works by estimating the power spectral density from the
    # data and then flattening the frequency response.
    # (1) The first option sets the duration in seconds of each
    #     sample of the data used as part of the PSD estimate.
    # (2) The second option sets the duration of the filter to apply
    whitened[ifo] = data[ifo].whiten(4, 4)

    zoom = whitened[ifo].time_slice(m.time - 0.5, m.time + 0.5)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.ylabel('Whitened Strain')
pylab.xlabel('Time (s)')
pylab.legend()
pylab.show()

# %% [markdown]
# We will now bandpass the data around GW150914 between 30 - 250 Hz. This will remove frequency ranges which won't contribute to this kind of signal and make it possible to see the signal in question.

# %%
for ifo in whitened:
    # Apply a highpass filter (at 30 Hz) followed by an lowpass filter (at 250 Hz)
    bpsd = whitened[ifo].highpass_fir(30, 512).lowpass_fir(250, 512)
    
    zoom = bpsd.time_slice(m.time - 0.5, m.time + 0.5)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.grid()
pylab.legend()
pylab.show()

# %% [markdown]
# #### Focus the Plot around GW150914
#
# In the above plot we can see that there is some excess signal that sticks above the noise. Let's zoom around this time now, and align the two time series.

# %%
pylab.figure(figsize=[15, 3])
for ifo in whitened:
    # Apply a highpass filter (at 30 Hz) followed by an lowpass filter (at 250 Hz)
    bpsd = whitened[ifo].highpass_fir(30, 512).lowpass_fir(250, 512)
    
    # We'll choose a tighter zoom here.
    zoom = bpsd.time_slice(m.time - 0.2, m.time + .1)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.grid()
pylab.legend()
pylab.show()

# %%
pylab.figure(figsize=[15, 3])
for ifo in whitened:
    # Apply a highpass filter (at 30 Hz) followed by an lowpass filter (at 250 Hz)
    bpsd = whitened[ifo].highpass_fir(30, 512).lowpass_fir(250, 512)
    
   
    # Now we'll specially align the L1 data. Where does this come from?
    # (1) We already knew that the signal was ~ 7 ms separated between detectors.
    # (2) The two LIGO interferometers are roughly aligned so that the output of
    #     one is a sign change of the other for *many* sky locations. This is an
    #     approximation and doesn't hold for all possible source sky locations.
    # A later tutorial will show how to estimate this alignment more precisely.
    if ifo == 'L1':
        bpsd.roll(int(bpsd.sample_rate * .007))
        bpsd *= -1
    
    # We'll choose a tighter zoom here.
    zoom = bpsd.time_slice(m.time - 0.2, m.time + .1)
    pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.grid()
pylab.legend()
pylab.show()

#test

pylab.figure(figsize=[15, 3])
for ifo in whitened:
    bpsd = whitened[ifo].highpass_fir(30, 512).lowpass_fir(250, 512)
    
    if ifo == 'L1':
        #bpsd.roll(int(bpsd.sample_rate * .007))
        bpsd *= -1
        zoom = bpsd.time_slice(m.time - 0.2, m.time + .1)
        pylab.plot(zoom.sample_times+0.007, zoom, label=ifo)
    else:
        zoom = bpsd.time_slice(m.time - 0.2, m.time + .1)
        pylab.plot(zoom.sample_times, zoom, label=ifo)

pylab.grid()
pylab.legend()
pylab.show()

# %% [markdown]
# We can now see that there is a coherent signal that matches in phase for a few cycles, which ends at about 0.44 on the plot above.

# %% [markdown]
# #### Visualizing excesses in the data with a Q-transform plot
#
# A common way to visualize gravitational-wave data is with a time-frequency representation known as the [constant-Q transform](https://en.wikipedia.org/wiki/Constant-Q_transform). It is similar to a standard spectrogram made with short-time Fourier transforms with the advantage that frequency bins are more sparsely spaced at high freqeuncys.

# %%
for ifo in whitened:
    # We'll choose a tighter zoom here.
    zoom = whitened[ifo].time_slice(m.time - 5, m.time + 5)
                    
    # The qtransform method returns a vector of the sample times, frequencies, and a 2-d vector of the 
    # power in each time-frequency bin. The free parameter is the choice of the Q-value. Larger Q-values
    # are generally more appropriate for viewing long duration features of the data and vice versa. 
                    
    # The options here:
    # (1) The time spacing for the output image (i.e. 1 ms in this case)
    # (2) The number of frequency bins in the output, logarithmically spaced
    # (3) The qrange to maximize over. We'll pick a constant at 8 here
    #     Typically higher values will be more appropriate for longer duration
    #     signals
    # (4) The frequency range to output
    times, freqs, power = zoom.qtransform(.001, logfsteps=100,
                                                qrange=(8, 8),
                                                frange=(20, 512),
                                         )
    pylab.figure(figsize=[15, 3])
    pylab.pcolormesh(times, freqs, power**0.5)
    pylab.xlim(m.time - 0.5, m.time + 0.3)
    pylab.title(ifo)
    pylab.yscale('log')
    pylab.show()

# %% [markdown]
# The GW150914 signal is relatively clear in the qtransform output, which is why the Q-transform can be a powerful diagnostic. However, note that quieter signals, especially those with lower masses than GW150914 had, will be harder to spot visually. In practice, we use a technique called [matched filtering](https://en.wikipedia.org/wiki/Matched_filter) to find signals in our data.

# %% [markdown]
# ## Challenge Problem
#
# Use the methods demonstrated above to see if you can visually spot a chirping signal in these data sets. Which of them contain a signal? Which contains just Gaussian noise?
#
# Information that may be useful:
#
# * Signals are all placed between 100 and 120 seconds into the frame file.
# * Try whitening the data, then plotting the qtransform.
# * Each file starts at gps time 0, and ends at gps time 128
# * The channel name in each file is "H1:TEST-STRAIN"

# %%
# Download the challenge set files
from six.moves.urllib import request

def get_file(fname):
    url = "https://github.com/ahnitz/odw-storage/raw/master/{}"
    url = url.format(fname)
    request.urlretrieve(url, fname)
    print('Getting : {}'.format(url))

files = ['PyCBC_T2_0.gwf', 'PyCBC_T2_1.gwf', 'PyCBC_T2_2.gwf',
         'PyCBC_T2_3.gwf', 'PyCBC_T2_4.gwf']

for fname in files:
    get_file(fname)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/urllib/request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File ~/anaconda3/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~/anaconda3/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~/anaconda3/lib/python3.9/http/client.py:1447, in HTTPSConnection.connect(self)
#    1445 "Connect to a host on a given (SSL) port."
# -> 1447 super().connect()
#    1449 if self._tunnel_host:
#
# File ~/anaconda3/lib/python3.9/http/client.py:946, in HTTPConnection.connect(self)
#     945 """Connect to the host and port specified in __init__."""
# --> 946 self.sock = self._create_connection(
#     947     (self.host,self.port), self.timeout, self.source_address)
#     948 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~/anaconda3/lib/python3.9/socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
#     846     # Break explicitly a reference cycle
#
# File ~/anaconda3/lib/python3.9/socket.py:832, in create_connection(address, timeout, source_address)
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 13>()
#      10 files = ['PyCBC_T2_0.gwf', 'PyCBC_T2_1.gwf', 'PyCBC_T2_2.gwf',
#      11          'PyCBC_T2_3.gwf', 'PyCBC_T2_4.gwf']
#      13 for fname in files:
# ---> 14     get_file(fname)
#
# Input In [1], in get_file(fname)
#       5 url = "https://github.com/ahnitz/odw-storage/raw/master/{}"
#       6 url = url.format(fname)
# ----> 7 request.urlretrieve(url, fname)
#       8 print('Getting : {}'.format(url))
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:555, in OpenerDirector.error(self, proto, *args)
#     553     http_err = 0
#     554 args = (dict, proto, meth_name) + args
# --> 555 result = self._call_chain(*args)
#     556 if result:
#     557     return result
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:747, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     744 fp.read()
#     745 fp.close()
# --> 747 return self.parent.open(new, timeout=req.timeout)
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:1349, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
# -> 1349         raise URLError(err)
#    1350     r = h.getresponse()
#    1351 except:
#
# URLError: <urlopen error [Errno 111] Connection refused>

# %%
import pycbc.frame
import pylab

# example of reading the strain in (note this is the same as in PyCBC tutorial 1)
ts = {}

ts[0] = pycbc.frame.read_frame('PyCBC_T2_0.gwf', 'H1:TEST-STRAIN', 0, 128)
ts[1] = pycbc.frame.read_frame('PyCBC_T2_1.gwf', 'H1:TEST-STRAIN', 0, 128)
ts[2] = pycbc.frame.read_frame('PyCBC_T2_2.gwf', 'H1:TEST-STRAIN', 0, 128)
ts[3] = pycbc.frame.read_frame('PyCBC_T2_3.gwf', 'H1:TEST-STRAIN', 0, 128)
ts[4] = pycbc.frame.read_frame('PyCBC_T2_4.gwf', 'H1:TEST-STRAIN', 0, 128)

'''
for i in range(len(ts)):
    pylab.plot(ts[i].sample_times, ts[i])
    pylab.ylabel('Strain')
    pylab.xlabel('GPS Time (s)')
    pylab.show()
'''
# Out:
# "\nfor i in range(len(ts)):\n    pylab.plot(ts[i].sample_times, ts[i])\n    pylab.ylabel('Strain')\n    pylab.xlabel('GPS Time (s)')\n    pylab.show()\n"

# %%
# Whitening and filtering
for i in range(len(ts)):
    whitened = ts[i].whiten(4, 4)

    bpsd = whitened.highpass_fir(30, 512).lowpass_fir(250, 512)

    zoom = bpsd.time_slice(100, 120)
    pylab.plot(zoom.sample_times, zoom)

    pylab.ylabel('Whitened Strain')
    pylab.xlabel('Time (s)')
    pylab.grid()
    pylab.show()

# %%
#plotting qtransform

bpsd = {}
zoom = {}

for i in range(5):
    bpsd[i] = ts[i].whiten(4, 4).highpass_fir(30, 512).lowpass_fir(250, 512)
    zoom[i] = bpsd[i].time_slice(100,120)

    times, freqs, power = zoom[i].qtransform(.001, logfsteps=100,
                                                qrange=(8, 8),
                                                frange=(30, 250),
                                         )

    pylab.figure(figsize=[15, 3])
    pylab.pcolormesh(times, freqs, power**0.5)
    pylab.xlim(100,120)
    pylab.yscale('log')
    pylab.show()
# Out:
# /home/iris/anaconda3/envs/pytorch1121/lib/python3.6/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   app.launch_new_instance()

# %%
#plotting signals

times, freqs, power = zoom[0].qtransform(.001, logfsteps=100,
                                            qrange=(8, 8),
                                            frange=(30, 250),
                                     )

pylab.figure(figsize=[15, 3])
pylab.pcolormesh(times, freqs, power**0.5)
pylab.xlim(117.7,118.02)
pylab.title('PyCBC_T2_0.gwf')
pylab.yscale('log')
pylab.show()

times, freqs, power = zoom[2].qtransform(.001, logfsteps=100,
                                            qrange=(8, 8),
                                            frange=(30, 250),
                                     )

pylab.figure(figsize=[15, 3])
pylab.pcolormesh(times, freqs, power**0.5)
pylab.xlim(106.4,107.02)
pylab.title('PyCBC_T2_2.gwf')
pylab.yscale('log')
pylab.show()

times, freqs, power = zoom[3].qtransform(.001, logfsteps=100,
                                            qrange=(8, 8),
                                            frange=(30, 250),
                                     )

pylab.figure(figsize=[15, 3])
pylab.pcolormesh(times, freqs, power**0.5)
pylab.xlim(115.8,116.1)
pylab.title('PyCBC_T2_3.gwf')
pylab.yscale('log')
pylab.show()
# Out:
# /home/iris/anaconda3/envs/pytorch1121/lib/python3.6/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   if __name__ == '__main__':
# /home/iris/anaconda3/envs/pytorch1121/lib/python3.6/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# /home/iris/anaconda3/envs/pytorch1121/lib/python3.6/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
